# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
p1 = pd.Series([1,2,8,10,"",np.nan])
p1n
# Out:
# 0      1
# 1      2
# 2      8
# 3     10
# 4
# 5    NaN
# dtype: object

# %%
p1 = pd.date_range('20210101',periods=6,freq='Y')
p1
# Out:
# DatetimeIndex(['2021-12-31', '2022-12-31', '2023-12-31', '2024-12-31',
#                '2025-12-31', '2026-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
p1 = pd.DataFrame(np.random.randn(3,9))
p1
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.915052 -0.719849  0.044172  1.869661 -1.037813  0.953652 -0.494995
# 1  1.554218 -0.135236  1.055068  0.778305  1.684994  1.043192 -1.446435
# 2  1.214128 -0.939890  0.360835 -0.371087 -0.336182 -0.426155 -0.972629
#
#           7         8
# 0 -1.166739 -0.126181
# 1  2.009274 -1.586053
# 2  0.473596  0.584236

# %%
p1 = pd.DataFrame({
                   'A1':[12,1],
                   'A2':[61,7],
                   'A3':[71,15],
                   'A4':[90,45]
                   })
p1
# Out:
#    A1  A2  A3  A4
# 0  12  61  71  90
# 1   1   7  15  45

# %%
p1.dtypes
# Out:
# A1    int64
# A2    int64
# A3    int64
# A4    int64
# dtype: object

# %%
p2 = pd.read_csv("dataset/Automobile_data.csv")
p2
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
p2.head(10)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
# 5      5         audi        sedan        99.8   177.3         ohc
# 6      6         audi        wagon       105.8   192.7         ohc
# 7      9          bmw        sedan       101.2   176.8         ohc
# 8     10          bmw        sedan       101.2   176.8         ohc
# 9     11          bmw        sedan       101.2   176.8         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# ...

# %%
p2.tail(10)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 51     69      toyota      wagon        95.7   169.7         ohc
# 52     70      toyota      wagon        95.7   169.7         ohc
# 53     71      toyota      wagon        95.7   169.7         ohc
# 54     79      toyota      wagon       104.5   187.8        dohc
# 55     80  volkswagen      sedan        97.3   171.7         ohc
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 51             four          62               31   6918.0
# 52             four          62               27   7898.0
# 53             four          62               27   8778.0
# ...

# %%
p2.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
p2.columns
# Out:
# Index(['index', 'company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
p2.values
# Out:
# array([[0, 'alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four',
#         111, 21, 13495.0],
#        [1, 'alfa-romero', 'convertible', 88.6, 168.8, 'dohc', 'four',
#         111, 21, 16500.0],
#        [2, 'alfa-romero', 'hatchback', 94.5, 171.2, 'ohcv', 'six', 154,
#         19, 16500.0],
#        [3, 'audi', 'sedan', 99.8, 176.6, 'ohc', 'four', 102, 24, 13950.0],
#        [4, 'audi', 'sedan', 99.4, 176.6, 'ohc', 'five', 115, 18, 17450.0],
#        [5, 'audi', 'sedan', 99.8, 177.3, 'ohc', 'five', 110, 19, 15250.0],
#        [6, 'audi', 'wagon', 105.8, 192.7, 'ohc', 'five', 110, 19,
#         18920.0],
#        [9, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101, 23, 16430.0],
#        [10, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'four', 101, 23,
#         16925.0],
#        [11, 'bmw', 'sedan', 101.2, 176.8, 'ohc', 'six', 121, 21, 20970.0],
#        [13, 'bmw', 'sedan', 103.5, 189.0, 'ohc', 'six', 182, 16, 30760.0],
# ...

# %%
p2.describe()
# Out:
#            index  wheel-base      length  horsepower  average-mileage  \
# count  61.000000   61.000000   61.000000   61.000000        61.000000
# mean   40.885246   98.481967  173.098361  107.852459        25.803279
# std    25.429706    6.679234   14.021846   53.524398         8.129821
# min     0.000000   88.400000  141.100000   48.000000        13.000000
# 25%    18.000000   94.500000  159.100000   68.000000        19.000000
# 50%    39.000000   96.300000  171.200000  100.000000        25.000000
# 75%    61.000000  101.200000  177.300000  123.000000        31.000000
# max    88.000000  120.900000  208.100000  288.000000        47.000000
#
#               price
# count     58.000000
# mean   15387.000000
# std    11320.259841
# min     5151.000000
# 25%     6808.500000
# 50%    11095.000000
# 75%    18120.500000
# max    45400.000000

# %%
p2.T
# Out:
#                            0            1            2        3        4   \
# index                       0            1            2        3        4
# company           alfa-romero  alfa-romero  alfa-romero     audi     audi
# body-style        convertible  convertible    hatchback    sedan    sedan
# wheel-base               88.6         88.6         94.5     99.8     99.4
# length                  168.8        168.8        171.2    176.6    176.6
# engine-type              dohc         dohc         ohcv      ohc      ohc
# num-of-cylinders         four         four          six     four     five
# horsepower                111          111          154      102      115
# average-mileage            21           21           19       24       18
# price                 13495.0      16500.0      16500.0  13950.0  17450.0
#
#                        5        6        7        8        9   ...      51  \
# index                   5        6        9       10       11  ...      69
# ...

# %%
p2.sort_index(axis=1,ascending=False)
# Out:
#     wheel-base    price num-of-cylinders  length  index  horsepower  \
# 0         88.6  13495.0             four   168.8      0         111
# 1         88.6  16500.0             four   168.8      1         111
# 2         94.5  16500.0              six   171.2      2         154
# 3         99.8  13950.0             four   176.6      3         102
# 4         99.4  17450.0             five   176.6      4         115
# ..         ...      ...              ...     ...    ...         ...
# 56        97.3   7975.0             four   171.7     81          85
# 57        97.3   7995.0             four   171.7     82          52
# 58        97.3   9995.0             four   171.7     86         100
# 59       104.3  12940.0             four   188.8     87         114
# 60       104.3  13415.0             four   188.8     88         114
#
#    engine-type      company   body-style  average-mileage
# 0         dohc  alfa-romero  convertible               21
# ...

# %%
p2.sort_values(by="price")
# Out:
#     index        company body-style  wheel-base  length engine-type  \
# 13     16      chevrolet  hatchback        88.4   141.1           l
# 27     36          mazda  hatchback        93.1   159.1         ohc
# 48     66         toyota  hatchback        95.7   158.7         ohc
# 36     49     mitsubishi  hatchback        93.7   157.3         ohc
# 28     37          mazda  hatchback        93.1   159.1         ohc
# ..    ...            ...        ...         ...     ...         ...
# 11     14            bmw      sedan       103.5   193.8         ohc
# 35     47  mercedes-benz    hardtop       112.0   199.2        ohcv
# 22     31          isuzu      sedan        94.5   155.9         ohc
# 23     32          isuzu      sedan        94.5   155.9         ohc
# 47     63        porsche  hatchback        98.4   175.7       dohcv
#
#    num-of-cylinders  horsepower  average-mileage    price
# 13            three          48               47   5151.0
# ...

# %%
p2["price"]
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, Length: 61, dtype: float64

# %%
p2[2:20]
# Out:
#     index      company body-style  wheel-base  length engine-type  \
# 2       2  alfa-romero  hatchback        94.5   171.2        ohcv
# 3       3         audi      sedan        99.8   176.6         ohc
# 4       4         audi      sedan        99.4   176.6         ohc
# 5       5         audi      sedan        99.8   177.3         ohc
# 6       6         audi      wagon       105.8   192.7         ohc
# 7       9          bmw      sedan       101.2   176.8         ohc
# 8      10          bmw      sedan       101.2   176.8         ohc
# 9      11          bmw      sedan       101.2   176.8         ohc
# 10     13          bmw      sedan       103.5   189.0         ohc
# 11     14          bmw      sedan       103.5   193.8         ohc
# 12     15          bmw      sedan       110.0   197.0         ohc
# 13     16    chevrolet  hatchback        88.4   141.1           l
# 14     17    chevrolet  hatchback        94.5   155.9         ohc
# ...

# %%
p2.loc[:,["price","length"]]
# Out:
#       price  length
# 0   13495.0   168.8
# 1   16500.0   168.8
# 2   16500.0   171.2
# 3   13950.0   176.6
# 4   17450.0   176.6
# ..      ...     ...
# 56   7975.0   171.7
# 57   7995.0   171.7
# 58   9995.0   171.7
# 59  12940.0   188.8
# 60  13415.0   188.8
#
# [61 rows x 2 columns]

# %%
p2.loc[10:30,["price","length"]]
# Out:
#       price  length
# 10  30760.0   189.0
# 11  41315.0   193.8
# 12  36880.0   197.0
# 13   5151.0   141.1
# 14   6295.0   155.9
# 15   6575.0   158.8
# 16   6377.0   157.3
# 17   6229.0   157.3
# 18   7295.0   157.1
# 19  12945.0   175.4
# 20  10345.0   169.1
# 21   6785.0   170.7
# 22      NaN   155.9
# 23      NaN   155.9
# 24  32250.0   199.6
# 25  35550.0   199.6
# 26  36000.0   191.7
# 27   5195.0   159.1
# 28   6095.0   159.1
# 29   6795.0   159.1
# 30  11845.0   169.0

# %%
p2.iloc[2:5,2:5]
# Out:
#   body-style  wheel-base  length
# 2  hatchback        94.5   171.2
# 3      sedan        99.8   176.6
# 4      sedan        99.4   176.6

# %%
p2.iloc[[1,2,6,8,9],[0,2]]
# Out:
#    index   body-style
# 1      1  convertible
# 2      2    hatchback
# 6      6        wagon
# 8     10        sedan
# 9     11        sedan

# %%
p2.iat[1,1]
# Out:
# 'alfa-romero'

# %%
p2[p2.price > 12000]
# Out:
#     index        company   body-style  wheel-base  length engine-type  \
# 0       0    alfa-romero  convertible        88.6   168.8        dohc
# 1       1    alfa-romero  convertible        88.6   168.8        dohc
# 2       2    alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3           audi        sedan        99.8   176.6         ohc
# 4       4           audi        sedan        99.4   176.6         ohc
# 5       5           audi        sedan        99.8   177.3         ohc
# 6       6           audi        wagon       105.8   192.7         ohc
# 7       9            bmw        sedan       101.2   176.8         ohc
# 8      10            bmw        sedan       101.2   176.8         ohc
# 9      11            bmw        sedan       101.2   176.8         ohc
# 10     13            bmw        sedan       103.5   189.0         ohc
# 11     14            bmw        sedan       103.5   193.8         ohc
# ...

# %%
p3 = p2.copy()
p3
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
p3["price"]=" "

# %%
p3
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage price
# 0              four         111               21
# ...

# %%
p2
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
p1[p1 > 0] = -p1
p1
# Out:
#    A1  A2  A3  A4
# 0 -12 -61 -71 -90
# 1  -1  -7 -15 -45

# %%
p2.dropna()
p2
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
p2.fillna(value=20)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
pd.isnull(p2)
# Out:
#     index  company  body-style  wheel-base  length  engine-type  \
# 0   False    False       False       False   False        False
# 1   False    False       False       False   False        False
# 2   False    False       False       False   False        False
# 3   False    False       False       False   False        False
# 4   False    False       False       False   False        False
# ..    ...      ...         ...         ...     ...          ...
# 56  False    False       False       False   False        False
# 57  False    False       False       False   False        False
# 58  False    False       False       False   False        False
# 59  False    False       False       False   False        False
# 60  False    False       False       False   False        False
#
#     num-of-cylinders  horsepower  average-mileage  price
# 0              False       False            False  False
# 1              False       False            False  False
# ...

# %%
p2.mean()
# Out:
# /tmp/ipykernel_13605/728296687.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   p2.mean()
# index                 40.885246
# wheel-base            98.481967
# length               173.098361
# horsepower           107.852459
# average-mileage       25.803279
# price              15387.000000
# dtype: float64

# %%
p2.mean(axis=1)
# Out:
# /tmp/ipykernel_13605/2671104860.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   p2.mean(axis=1)
# 0     2314.066667
# 1     2815.066667
# 2     2823.450000
# 3     2392.566667
# 4     2977.166667
#          ...
# 56    1406.166667
# 57    1405.833333
# 58    1746.000000
# 59    2242.850000
# 60    2322.183333
# Length: 61, dtype: float64

# %%
p4 = pd.Series([1,3,5,np.nan,6,8]).shift(2)
p4
# Out:
# 0    NaN
# 1    NaN
# 2    1.0
# 3    3.0
# 4    5.0
# 5    NaN
# dtype: float64

# %%
p2.sub(p4)
# Out:
#      0   1   2   3   4   5  average-mileage body-style company engine-type  \
# 0  NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 1  NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 2  NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 3  NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 4  NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# ..  ..  ..  ..  ..  ..  ..              ...        ...     ...         ...
# 56 NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 57 NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 58 NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 59 NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
# 60 NaN NaN NaN NaN NaN NaN              NaN        NaN     NaN         NaN
#
#     horsepower  index  length num-of-cylinders  price  wheel-base
# ...

# %%
p2.value_counts()
# Out:
# index  company        body-style   wheel-base  length  engine-type  num-of-cylinders  horsepower  average-mileage  price
# 0      alfa-romero    convertible  88.6        168.8   dohc         four              111         21               13495.0    1
# 61     porsche        hardtop      89.5        168.9   ohcf         six               207         17               34028.0    1
# 45     mercedes-benz  wagon        110.0       190.9   ohc          five              123         22               28248.0    1
# 46     mercedes-benz  sedan        120.9       208.1   ohcv         eight             184         14               40960.0    1
# 47     mercedes-benz  hardtop      112.0       199.2   ohcv         eight             184         14               45400.0    1
# 49     mitsubishi     hatchback    93.7        157.3   ohc          four              68          37               5389.0     1
# ...

# %%
p5 = [p2[0:10],p2[10:20],p2[20:30]]
p5
# Out:
# [   index      company   body-style  wheel-base  length engine-type  \
#  0      0  alfa-romero  convertible        88.6   168.8        dohc
#  1      1  alfa-romero  convertible        88.6   168.8        dohc
#  2      2  alfa-romero    hatchback        94.5   171.2        ohcv
#  3      3         audi        sedan        99.8   176.6         ohc
#  4      4         audi        sedan        99.4   176.6         ohc
#  5      5         audi        sedan        99.8   177.3         ohc
#  6      6         audi        wagon       105.8   192.7         ohc
#  7      9          bmw        sedan       101.2   176.8         ohc
#  8     10          bmw        sedan       101.2   176.8         ohc
#  9     11          bmw        sedan       101.2   176.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
#  0             four         111               21  13495.0
#  1             four         111               21  16500.0
# ...

# %%
pd.concat(p5)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
pd.merge(right,left)
# Out:
#    key  rval  lval
# 0  foo     4     1
# 1  foo     4     2
# 2  foo     5     1
# 3  foo     5     2

# %%
p2.append([1,3])
# Out:
#       0  average-mileage   body-style      company engine-type  horsepower  \
# 0   NaN             21.0  convertible  alfa-romero        dohc       111.0
# 1   NaN             21.0  convertible  alfa-romero        dohc       111.0
# 2   NaN             19.0    hatchback  alfa-romero        ohcv       154.0
# 3   NaN             24.0        sedan         audi         ohc       102.0
# 4   NaN             18.0        sedan         audi         ohc       115.0
# ..  ...              ...          ...          ...         ...         ...
# 58  NaN             26.0        sedan   volkswagen         ohc       100.0
# 59  NaN             23.0        sedan        volvo         ohc       114.0
# 60  NaN             23.0        wagon        volvo         ohc       114.0
# 0   1.0              NaN          NaN          NaN         NaN         NaN
# 1   3.0              NaN          NaN          NaN         NaN         NaN
#
#     index  length num-of-cylinders    price  wheel-base
# ...

# %%
p2.append(p2)
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
p2.groupby("price").sum().sort_values("index")
# Out:
#          index  wheel-base  length  horsepower  average-mileage
# price
# 13495.0      0        88.6   168.8         111               21
# 16500.0      3       183.1   340.0         265               40
# 13950.0      3        99.8   176.6         102               24
# 17450.0      4        99.4   176.6         115               18
# 15250.0      5        99.8   177.3         110               19
# 18920.0      6       105.8   192.7         110               19
# 16430.0      9       101.2   176.8         101               23
# 16925.0     10       101.2   176.8         101               23
# 20970.0     11       101.2   176.8         121               21
# 30760.0     13       103.5   189.0         182               16
# 41315.0     14       103.5   193.8         182               16
# 36880.0     15       110.0   197.0         182               15
# 5151.0      16        88.4   141.1          48               47
# 6295.0      17        94.5   155.9          70               38
# ...

# %%
p2.groupby(["price","length"]).sum().sort_values("length")
# Out:
#                 index  wheel-base  horsepower  average-mileage
# price   length
# 5151.0  141.1      16        88.4          48               47
# 6295.0  155.9      17        94.5          70               38
# 7295.0  157.1      27        96.5          76               30
# 6377.0  157.3      19        93.7          68               31
# 5389.0  157.3      49        93.7          68               37
# 6189.0  157.3      50        93.7          68               31
# 6229.0  157.3      20        93.7          68               31
# 6338.0  158.7      67        95.7          62               31
# 6488.0  158.7      68        95.7          62               31
# 5348.0  158.7      66        95.7          62               35
# 6575.0  158.8      18        94.5          70               38
# 6795.0  159.1      38        93.1          68               31
# 5195.0  159.1      36        93.1          68               30
# 6095.0  159.1      37        93.1          68               31
# ...

# %%
p2.groupby(["length","price"]).sum().sort_values("length")
# Out:
#                 index  wheel-base  horsepower  average-mileage
# length price
# 141.1  5151.0      16        88.4          48               47
# 155.9  6295.0      17        94.5          70               38
# 157.1  7295.0      27        96.5          76               30
# 157.3  5389.0      49        93.7          68               37
#        6189.0      50        93.7          68               31
#        6229.0      20        93.7          68               31
#        6377.0      19        93.7          68               31
# 158.7  5348.0      66        95.7          62               35
#        6338.0      67        95.7          62               31
#        6488.0      68        95.7          62               31
# 158.8  6575.0      18        94.5          70               38
# 159.1  6095.0      37        93.1          68               31
#        6795.0      38        93.1          68               31
#        5195.0      36        93.1          68               30
# ...

# %%
p6 = p2.stack()
p6
# Out:
# 0   index                         0
#     company             alfa-romero
#     body-style          convertible
#     wheel-base                 88.6
#     length                    168.8
#                            ...
# 60  engine-type                 ohc
#     num-of-cylinders           four
#     horsepower                  114
#     average-mileage              23
#     price                   13415.0
# Length: 607, dtype: object

# %%
p6.unstack()
# Out:
#    index      company   body-style wheel-base length engine-type  \
# 0      0  alfa-romero  convertible       88.6  168.8        dohc
# 1      1  alfa-romero  convertible       88.6  168.8        dohc
# 2      2  alfa-romero    hatchback       94.5  171.2        ohcv
# 3      3         audi        sedan       99.8  176.6         ohc
# 4      4         audi        sedan       99.4  176.6         ohc
# ..   ...          ...          ...        ...    ...         ...
# 56    81   volkswagen        sedan       97.3  171.7         ohc
# 57    82   volkswagen        sedan       97.3  171.7         ohc
# 58    86   volkswagen        sedan       97.3  171.7         ohc
# 59    87        volvo        sedan      104.3  188.8         ohc
# 60    88        volvo        wagon      104.3  188.8         ohc
#
#    num-of-cylinders horsepower average-mileage    price
# 0              four        111              21  13495.0
# 1              four        111              21  16500.0
# ...

# %%
p7 = p2.cumsum()
p7.plot()
# Out:
# <AxesSubplot:>

# %%
p2.plot(x="price",y="length",kind="scatter")
# Out:
# <AxesSubplot:xlabel='price', ylabel='length'>

# %%
p2.plot(x="price",y="length",kind="bar")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
p7 = p2.cumsum()
p7.plot(x="price",y="length",kind="scatter")
# Out:
# <AxesSubplot:xlabel='price', ylabel='length'>

# %%
p7 = p2.cummax()
p7.plot(x="price",y="length",kind="scatter")
# Out:
# <AxesSubplot:xlabel='price', ylabel='length'>

# %%
plt.figure()
p2.plot()
plt.legend(loc='best')
